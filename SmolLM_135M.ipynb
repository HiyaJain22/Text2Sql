# %%
# !pip install datasets
from transformers import AutoModelForCausalLM, AutoTokenizer
checkpoint = "HuggingFaceTB/SmolLM-135M-Instruct"
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (3.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.6)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.26.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.17.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets) (0.2.0)

# %%
device = "cuda" # for GPU usage or "cpu" for CPU usage
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# for multiple GPUs install accelerate and do `model = AutoModelForCausalLM.from_pretrained(checkpoint, device_map="auto")`
model = AutoModelForCausalLM.from_pretrained(checkpoint).to(device)

# %% [markdown]
# # Pretrained SmolLM

# %%
def chat_template(question, context):
    template = f"""\
    You are a SQL expert. Given the Schema, generate a SQL query for the question asked.
    Schema:{context}
    question:{question}
    """
    # Remove any leading whitespace characters from each line in the template.
    template = "\n".join([line.lstrip() for line in template.splitlines()])
    return template

# %%
def model_response(question, context):
  # Tokenize the input with attention mask
  inputs = tokenizer(
      chat_template(question, context),
      return_tensors="pt",
      padding=True,
      truncation=True
  ).to(device)

  # Generate the output
  outputs = model.generate(
      inputs["input_ids"],
      attention_mask=inputs["attention_mask"],  # Ensure attention mask is passed
      max_new_tokens=50,
      temperature=0.1,
      top_p=0.99,
      do_sample=True,
      return_dict_in_generate=True,
  )

  # Decode and print the output
  response = tokenizer.decode(outputs.sequences[0], skip_special_tokens=True)
  print(response)

# %%
question = "How many heads of the departments are older than 56 ?"
context = "CREATE TABLE head (age INTEGER)"
model_response(question, context)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# SELECT SUM(age) FROM head WHERE age > 56

# %%
question = "List the name, born state and age of the heads of departments ordered by age."
context = "CREATE TABLE head (name VARCHAR, born_state VARCHAR, age VARCHAR)"
model_response(question, context)
# Out:
# SELECT name FROM head WHERE born_state = "d departments" AND age = "order"

# %%
question = "What are the themes of farm competitions sorted by year in ascending order?"
context = "CREATE TABLE farm_competition (Theme VARCHAR, YEAR VARCHAR)"
model_response(question, context)
# Out:
# SELECT theme FROM farm_competition WHERE YEAR = " ascending order"

# %% [markdown]
# # Finetuning SmolLM

# %%
from datasets import load_dataset, Dataset
# Define the dataset for fine-tuning
dataset_id = "b-mc2/sql-create-context"

data = load_dataset(dataset_id, split="train")
df = data.to_pandas()
# Out:
# README.md:   0%|          | 0.00/4.43k [00:00<?, ?B/s]
# sql_create_context_v4.json:   0%|          | 0.00/21.8M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/78577 [00:00<?, ? examples/s]

# %%
def chat_template_for_training(context, answer, question):
    template = f"""\
    <|im_start|>user
    You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
    Schema:{context}
    question:{question}
    <|im_end|>
    <|im_start|>assistant
    {answer}
    <|im_end|>
    """
    # Remove any leading whitespace characters from each line in the template.
    template = "\n".join([line.lstrip() for line in template.splitlines()])
    return template

# %%
# Apply the chat_template_for_training function to each row in the
# dataframe and store the result in a new "text" column.
df["text"] = df.apply(lambda x: chat_template_for_training(x["context"],
x["answer"], x["question"]), axis=1)

# Convert the dataframe back to a Dataset object.
formatted_data = Dataset.from_pandas(df)

# %%
# Load and prepare dataset
dataset_id = "b-mc2/sql-create-context"
data = load_dataset(dataset_id, split="train")
df = data.to_pandas()

# Prepare training data
def prepare_training_features(examples):
    inputs = [chat_template(q, c) for q, c in zip(examples["question"], examples["context"])]
    model_inputs = tokenizer(
        inputs,
        max_length=512,
        padding="max_length",
        truncation=True
    )

    # Tokenize targets
    labels = tokenizer(
        examples["answer"],
        max_length=128,
        padding="max_length",
        truncation=True
    )

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# Convert dataset to features
formatted_data = Dataset.from_pandas(df)
formatted_data = formatted_data.map(
    prepare_training_features,
    batched=True,
    remove_columns=formatted_data.column_names
)
# Out:
# Map:   0%|          | 0/78577 [00:00<?, ? examples/s]

# %%
from peft import LoraConfig, get_peft_model, PeftModel
from transformers import (
    AutoModelForCausalLM,
    Trainer,
    TrainingArguments,
    AutoTokenizer
)

# Configure LoRA for SmolLM
peft_config = LoraConfig(
    r=32,
    lora_alpha=64,
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM",  # Changed to CAUSAL_LM for SmolLM
    target_modules=[
        "q_proj",
        "k_proj",
        "v_proj",
        "o_proj"  # Added k_proj and o_proj for transformer attention
    ]
)

# Load base model
model = AutoModelForCausalLM.from_pretrained(
    checkpoint,  # Replace with your specific SmolLM checkpoint
    trust_remote_code=True,
    device_map="auto"
)
tokenizer = AutoTokenizer.from_pretrained(
    checkpoint,  # Replace with your specific SmolLM checkpoint
    trust_remote_code=True
)

# Apply LoRA to model
model = get_peft_model(model, peft_config)
model.print_trainable_parameters()

# Training arguments
training_args = TrainingArguments(
    output_dir="smollm-sql-v1",
    per_device_train_batch_size=4,  # Reduced batch size due to model size
    gradient_accumulation_steps=4,   # Increased for stability
    learning_rate=1e-4,             # Adjusted learning rate
    lr_scheduler_type="cosine",
    save_strategy="epoch",
    logging_steps=10,
    num_train_epochs=10,
    max_steps=5000,
    fp16=True,
    gradient_checkpointing=True,    # Added for memory efficiency
    optim="adamw_torch"            # Specified optimizer
)

# Initialize trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=formatted_data,
    tokenizer=tokenizer,
)

# Train the model
trainer.train()

# Save the final model
trainer.save_model("smollm-sql-v1-final")

# Load and merge the fine-tuned model
base_model = AutoModelForCausalLM.from_pretrained(
    checkpoint,
    trust_remote_code=True,
    device_map="auto"
)
peft_model = PeftModel.from_pretrained(
    base_model,
    "smollm-sql-v1-final",
    device_map="auto"
)
model = peft_model.merge_and_unload()

# Save the merged model
model.save_pretrained("smollm-sql-v1-merged")
# Out:
# <ipython-input-104-e9d4e609addc>:56: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# max_steps is given, it will override any value given in num_train_epochs
# trainable params: 3,686,400 || all params: 138,201,408 || trainable%: 2.6674
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-104-e9d4e609addc> in <cell line: 64>()
#      62
#      63 # Train the model
# ---> 64 trainer.train()
#      65
#      66 # Save the final model
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2121                 hf_hub_utils.enable_progress_bars()
#    2122         else:
# -> 2123             return inner_training_loop(
#    2124                 args=args,
#    2125                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2479                     )
#    2480                     with context():
# -> 2481                         tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2482
#    2483                     if (
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in training_step(self, model, inputs, num_items_in_batch)
#    3577
#    3578         with self.compute_loss_context_manager():
# -> 3579             loss = self.compute_loss(model, inputs, num_items_in_batch=num_items_in_batch)
#    3580
#    3581         del inputs
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in compute_loss(self, model, inputs, return_outputs, num_items_in_batch)
#    3631                 loss_kwargs["num_items_in_batch"] = num_items_in_batch
#    3632             inputs = {**inputs, **loss_kwargs}
# -> 3633         outputs = model(**inputs)
#    3634         # Save past state if it exists
#    3635         # TODO: this needs to be fixed and made cleaner later.
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in forward(*args, **kwargs)
#     821
#     822     def forward(*args, **kwargs):
# --> 823         return model_forward(*args, **kwargs)
#     824
#     825     # To act like a decorator so that it can be popped when doing `extract_model_from_parallel`
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in __call__(self, *args, **kwargs)
#     809
#     810     def __call__(self, *args, **kwargs):
# --> 811         return convert_to_fp32(self.model_forward(*args, **kwargs))
#     812
#     813     def __getstate__(self):
#
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py in decorate_autocast(*args, **kwargs)
#      42     def decorate_autocast(*args, **kwargs):
#      43         with autocast_instance:
# ---> 44             return func(*args, **kwargs)
#      45
#      46     decorate_autocast.__script_unsupported = "@autocast() decorator is not supported in script mode"  # type: ignore[attr-defined]
#
# /usr/local/lib/python3.10/dist-packages/peft/peft_model.py in forward(self, input_ids, attention_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict, task_ids, **kwargs)
#    1642             with self._enable_peft_forward_hooks(**kwargs):
#    1643                 kwargs = {k: v for k, v in kwargs.items() if k not in self.special_peft_forward_args}
# -> 1644                 return self.base_model(
#    1645                     input_ids=input_ids,
#    1646                     attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/peft/tuners/tuners_utils.py in forward(self, *args, **kwargs)
#     195
#     196     def forward(self, *args: Any, **kwargs: Any):
# --> 197         return self.model.forward(*args, **kwargs)
#     198
#     199     def _pre_injection_hook(self, model: nn.Module, config: PeftConfig, adapter_name: str) -> None:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, num_logits_to_keep, **loss_kwargs)
#    1188
#    1189         # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1190         outputs = self.model(
#    1191             input_ids=input_ids,
#    1192             attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     913             position_ids = cache_position.unsqueeze(0)
#     914
# --> 915         causal_mask = self._update_causal_mask(
#     916             attention_mask, inputs_embeds, cache_position, past_key_values, output_attentions
#     917         )
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/llama/modeling_llama.py in _update_causal_mask(self, attention_mask, input_tensor, cache_position, past_key_values, output_attentions)
#    1002         # When output attentions is True, sdpa implementation's forward method calls the eager implementation's forward
#    1003         if self.config._attn_implementation == "sdpa" and not using_static_cache and not output_attentions:
# -> 1004             if AttentionMaskConverter._ignore_causal_mask_sdpa(
#    1005                 attention_mask,
#    1006                 inputs_embeds=input_tensor,
#
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_attn_mask_utils.py in _ignore_causal_mask_sdpa(attention_mask, inputs_embeds, past_key_values_length, sliding_window, is_training)
#     282             if len(attention_mask.shape) == 4:
#     283                 return False
# --> 284             elif not is_tracing and torch.all(attention_mask == 1):
#     285                 if query_length == 1 or key_value_length == query_length:
#     286                     # For query_length == 1, causal attention and bi-directional attention are the same.
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
# Disable cache to improve training speed.
model.config.use_cache = False

# Set the temperature for pretraining to 0.1.
model.config.pretraining_tp = 0.1

# %%
from peft import LoraConfig

# Define the PEFT configuration.
peft_config = LoraConfig(
    # Set the rank of the LoRA projection matrix.
    r=64,

    # Set the alpha parameter for the LoRA projection matrix.
    lora_alpha=64,

    # Set the dropout rate for the LoRA projection matrix.
    lora_dropout=0.05,

    # Set the bias term to "none".
    bias="none",

    # Set the task type to "SEQ_2_SEQ_LM".
    task_type="SEQ_2_SEQ_LM",
)

# %%
from transformers import TrainingArguments

# Define the training arguments.
training_args = TrainingArguments(
    # Set the output directory for the training run.
    output_dir="SmolLM-135M-Instruct-sqllm-v1",

    # Set the per-device training batch size.
    per_device_train_batch_size=6,

    # Set the number of gradient accumulation steps.
    gradient_accumulation_steps=2,

    # Set the optimizer to use.
    optim="paged_adamw_32bit",

    # Set the learning rate.
    learning_rate=2e-4,

    # Set the learning rate scheduler type.
    lr_scheduler_type="cosine",

    # Set the save strategy.
    save_strategy="epoch",

    # Set the logging steps.
    logging_steps=10,

    # Set the number of training epochs.
    num_train_epochs=10,

    # Set the maximum number of training steps.
    max_steps=500,

    # Enable fp16 training.
    fp16=True,
)

# %%
# !pip install trl bitsandbytes
# Out:
# Requirement already satisfied: trl in /usr/local/lib/python3.10/dist-packages (0.12.1)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.10/dist-packages (0.44.1)
# Requirement already satisfied: accelerate>=0.34.0 in /usr/local/lib/python3.10/dist-packages (from trl) (1.1.1)
# Requirement already satisfied: datasets>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from trl) (3.1.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from trl) (13.9.4)
# Requirement already satisfied: transformers>=4.46.0 in /usr/local/lib/python3.10/dist-packages (from trl) (4.46.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (2.5.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.34.0->trl) (0.26.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.34.0->trl) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.34.0->trl) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.34.0->trl) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.34.0->trl) (0.4.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.21.0->trl) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.21.0->trl) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.21.0->trl) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.21.0->trl) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.21.0->trl) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.21.0->trl) (4.66.6)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=2.21.0->trl) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.21.0->trl) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets>=2.21.0->trl) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.21.0->trl) (3.10.10)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->bitsandbytes) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.46.0->trl) (2024.9.11)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.46.0->trl) (0.20.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->trl) (2.18.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.21.0->trl) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.21.0->trl) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.21.0->trl) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.21.0->trl) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.21.0->trl) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.21.0->trl) (1.17.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.21.0->trl) (4.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->trl) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.21.0->trl) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.21.0->trl) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.21.0->trl) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.21.0->trl) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->bitsandbytes) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.21.0->trl) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.21.0->trl) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.21.0->trl) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.21.0->trl) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets>=2.21.0->trl) (0.2.0)

# %%
pip install --upgrade bitsandbytes
# Out:
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.10/dist-packages (0.44.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (2.5.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->bitsandbytes) (3.0.2)

# %%
import torch

# %%
from trl import SFTTrainer

# Initialize the SFTTrainer.
trainer = SFTTrainer(
    # Set the model to be trained.
    model=model,

    # Set the training dataset.
    train_dataset=formatted_data,

    # Set the PEFT configuration.
    peft_config=peft_config,

    # Set the name of the text field in the dataset.
    dataset_text_field="labels",

    # Set the training arguments.
    args=training_args,

    # Set the tokenizer.
    tokenizer=tokenizer,

    # Disable packing.
    packing=False,

#     # Set the maximum sequence length.
#     max_seq_length=1024
)

trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_deprecation.py:100: FutureWarning: Deprecated argument(s) used in '__init__': dataset_text_field. Will not be supported from version '0.13.0'.
#
# Deprecated positional argument(s) used in SFTTrainer, please use the SFTConfig to set these arguments instead.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:309: UserWarning: You didn't pass a `max_seq_length` argument to the SFTTrainer, this will default to 1024
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:328: UserWarning: You passed a `dataset_text_field` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# max_steps is given, it will override any value given in num_train_epochs
#     <div>
#
#       <progress value='22' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 22/500 00:11 < 04:35, 1.74 it/s, Epoch 0.00/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>0.009300</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.004000</td>
#     </tr>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-92-9fc2dd3ca189> in <cell line: 30>()
#      28 )
#      29
# ---> 30 trainer.train()
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2121                 hf_hub_utils.enable_progress_bars()
#    2122         else:
# -> 2123             return inner_training_loop(
#    2124                 args=args,
#    2125                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2484                         args.logging_nan_inf_filter
#    2485                         and not is_torch_xla_available()
# -> 2486                         and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    2487                     ):
#    2488                         # if loss is nan or inf simply add the average of previous logged losses
#
# KeyboardInterrupt:

# %%
from huggingface_hub import login
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# save locally
model.save_pretrained("SmolLM-135M-Instruct-sqllm-v1")

# push to the hub
model.push_to_hub("yashyaks/SmolLM-135M-Instruct-sqllm-v1")
# Out:
# README.md:   0%|          | 0.00/5.18k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/572M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/yashyaks/SmolLM-135M-Instruct-sqllm-v1/commit/e9490282976b3f9acea6eb7656212435dc0949db', commit_message='Upload BartForConditionalGeneration', commit_description='', oid='e9490282976b3f9acea6eb7656212435dc0949db', pr_url=None, repo_url=RepoUrl('https://huggingface.co/yashyaks/SmolLM-135M-Instruct-sqllm-v1', endpoint='https://huggingface.co', repo_type='model', repo_id='yashyaks/SmolLM-135M-Instruct-sqllm-v1'), pr_revision=None, pr_num=None)

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)

# %%
import torch

# %%
# from peft import AutoPeftModelForCausalLM, PeftModel

# # Load the pre-trained model.
# model = AutoModelForCausalLM.from_pretrained(
#     checkpoint,
#     # torch_dtype=torch.float16,
#     # load_in_8bit=False,
#     device_map="auto",
#     # trust_remote_code=True
# )

# # Load the PEFT model from a checkpoint.
# model_path = "/content/SmolLM-135M-Instruct-sqllm-v1/checkpoint-500"
# peft_model = PeftModel.from_pretrained(model, model_path, from_transformers=True, device_map="auto")

# # Wrap the model with the PEFT model.
# model = peft_model.merge_and_unload()

# %%
def finetune_response(question, context):
  # Encode the prompt.
  # inputs = tokenizer(prompt, return_tensors="pt").to('cuda')
  inputs = tokenizer(
        chat_template(question, context),
        return_tensors="pt",
        padding=True,
        truncation=True
    ).to(device)


  # Generate the output.
  # output = model.generate(**inputs)
  outputs = model.generate(
        inputs["input_ids"],
        attention_mask=inputs["attention_mask"],  # Ensure attention mask is passed
        max_new_tokens=50,
        temperature=0.1,
        top_p=0.99,
        do_sample=True,
        return_dict_in_generate=True,
    )

  response = tokenizer.decode(outputs.sequences[0], skip_special_tokens=True)
  print(response)
  return response

# %%
# Prepare the Prompt.
question = "How many heads of the departments are older than 56 ?"
context = "CREATE TABLE head (age INTEGER)"
finetune_response(question, context)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-ef2963d91196> in <cell line: 4>()
#       2 question = "How many heads of the departments are older than 56 ?"
#       3 context = "CREATE TABLE head (age INTEGER)"
# ----> 4 finetune_response(question, context)
#
# <ipython-input-88-d1072c9fa90c> in finetune_response(question, context)
#      12   # Generate the output.
#      13   # output = model.generate(**inputs)
# ---> 14   outputs = model.generate(
#      15         inputs["input_ids"],
#      16         attention_mask=inputs["attention_mask"],  # Ensure attention mask is passed
#
# TypeError: PeftModelForSeq2SeqLM.generate() takes 1 positional argument but 2 were given

# %%
# Prepare the Prompt.
question = "List the name, born state and age of the heads of departments ordered by age."
context = "CREATE TABLE head (name VARCHAR, born_state VARCHAR, age VARCHAR)"
finetune_response(question, context)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-fd38138f88ac> in <cell line: 4>()
#       2 question = "List the name, born state and age of the heads of departments ordered by age."
#       3 context = "CREATE TABLE head (name VARCHAR, born_state VARCHAR, age VARCHAR)"
# ----> 4 finetune_response(question, context)
#
# <ipython-input-88-d1072c9fa90c> in finetune_response(question, context)
#      12   # Generate the output.
#      13   # output = model.generate(**inputs)
# ---> 14   outputs = model.generate(
#      15         inputs["input_ids"],
#      16         attention_mask=inputs["attention_mask"],  # Ensure attention mask is passed
#
# TypeError: PeftModelForSeq2SeqLM.generate() takes 1 positional argument but 2 were given

# %%
# Prepare the Prompt.
question = "What are the themes of farm competitions sorted by year in ascending order?"
context = "CREATE TABLE farm_competition (Theme VARCHAR, YEAR VARCHAR)"
finetune_response(question, context)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-0eb1eaace0d2> in <cell line: 4>()
#       2 question = "What are the themes of farm competitions sorted by year in ascending order?"
#       3 context = "CREATE TABLE farm_competition (Theme VARCHAR, YEAR VARCHAR)"
# ----> 4 finetune_response(question, context)
#
# <ipython-input-88-d1072c9fa90c> in finetune_response(question, context)
#      12   # Generate the output.
#      13   # output = model.generate(**inputs)
# ---> 14   outputs = model.generate(
#      15         inputs["input_ids"],
#      16         attention_mask=inputs["attention_mask"],  # Ensure attention mask is passed
#
# TypeError: PeftModelForSeq2SeqLM.generate() takes 1 positional argument but 2 were given

# %%
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForCausalLM
from nltk.translate.bleu_score import sentence_bleu
import pandas as pd

# Load the dataset
dataset_id = "b-mc2/sql-create-context"
data = load_dataset(dataset_id, split="train")
df = data.to_pandas()

# # Load the model and tokenizer
# tokenizer = AutoTokenizer.from_pretrained("your-model-name")
# model = AutoModelForCausalLM.from_pretrained("your-model-name").to("cuda")

# Function to format the prompt
def chat_template(question, context):
    template = f"""\
    You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
    Schema:{context}
    question:{question}
    """
    return "\n".join([line.lstrip() for line in template.splitlines()])

# Function to calculate BLEU score
def calculate_bleu_score(predictions, references):
    if not predictions or not references:
        return 0.0  # Return 0 if either list is empty
    bleu_scores = []
    for pred, ref in zip(predictions, references):
        # Tokenize the predictions and references (split by spaces)
        pred_tokens = pred.split()
        ref_tokens = ref.split()
        bleu_score = sentence_bleu([ref_tokens], pred_tokens)
        bleu_scores.append(bleu_score)
    return sum(bleu_scores) / len(bleu_scores)

# Function to calculate Exact Match (EM) score
def calculate_exact_match(predictions, references):
    exact_matches = [1 if pred.strip() == ref.strip() else 0 for pred, ref in zip(predictions, references)]
    return sum(exact_matches) / len(exact_matches)

# Process the dataset
generated_sqls = []
reference_sqls = df["answer"].tolist()

for _, row in df.iterrows():
    question = row["question"]
    context = row["context"]
    # output
    generated_sql = finetune_response(question, context)
    generated_sqls.append(generated_sql)

# Calculate BLEU and Exact Match scores
bleu = calculate_bleu_score(generated_sqls, reference_sqls)
em = calculate_exact_match(generated_sqls, reference_sqls)

# Print results
for i, (gen, ref) in enumerate(zip(generated_sqls, reference_sqls)):
    print(f"Query {i+1}:")
    print(f"Generated: {gen}")
    print(f"Reference: {ref}")
    print("---")

print(f"BLEU score: {bleu:.4f}")
print(f"Exact Match (EM): {em:.4f}")
# Out:
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE head (age INTEGER)
# question:How many heads of the departments are older than 56 ?
#
# assistant
# SELECT MAX(head) FROM head
# #queryset
# #question
# #markdown formatting
# #schema
# #reserved
# # # question
# # # Markdown formatting
# # #schema
# # #reserved
# # # # #
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE head (name VARCHAR, born_state VARCHAR, age VARCHAR)
# question:List the name, born state and age of the heads of departments ordered by age.
#
# assistant
# SELECT name, born_state, age FROM head GROUP BY name, born_state
# # Lake Tahoe, California
# # Lake Tahoe, California
#
# SELECT name, born_state, age FROM head GROUP BY name, born
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE department (creation VARCHAR, name VARCHAR, budget_in_billions VARCHAR)
# question:List the creation year, name and budget of each department.
#
# assistant
# SELECT creation, name FROM department ORDER BY creation DESC LIMIT 1
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE department (budget_in_billions INTEGER)
# question:What are the maximum and minimum budget of the departments?
#
# assistant
# SELECT MAX(budget_in_billions) FROM department
# #
# #
# #
# #
# # Question:What is the maximum budget of the departments?
# # #
# # #
# # #
# # #
# # #
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE department (num_employees INTEGER, ranking INTEGER)
# question:What is the average number of employees of the departments whose rank is between 10 and 15?
#
# assistant
# SELECT AVG(num_employees) FROM department WHERE ranking < 10 AND ranking > 15
# question:What is the average number of employees of the departments whose rank is between 10 and 15?
#
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE head (name VARCHAR, born_state VARCHAR)
# question:What are the names of the heads who are born outside the California state?
#
# assistant
# SELECT name FROM head WHERE born_state = "California"
# question:What are the names of the heads who are born outside the California state?
#
# ```
#
# Your code should pass the SQL test if you don't want to markdown
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE department (creation VARCHAR, department_id VARCHAR); CREATE TABLE management (department_id VARCHAR, head_id VARCHAR); CREATE TABLE head (head_id VARCHAR, born_state VARCHAR)
# question:What are the distinct creation years of the departments managed by a secretary born in state 'Alabama'?
#
# assistant
# SELECT COUNT(department_id) FROM head AS T1 AS T2
# ```
# Output: The distinct creation years of the departments managed by a secretary born in state 'Alabama'
#
# Your code should pass the following test case
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE head (born_state VARCHAR)
# question:What are the names of the states where at least 3 heads were born?
#
# assistant
# SELECT born_state FROM head WHERE 3 AS AS MADE_VARCHAR
# question:What are the names of the states where at least 3 heads were born?
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE department (creation VARCHAR)
# question:In which year were most departments established?
#
# assistant
# SELECT creation FROM department GROUP BY creation ORDER BY creation DESC LIMIT 1
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE management (department_id VARCHAR, temporary_acting VARCHAR); CREATE TABLE department (name VARCHAR, num_employees VARCHAR, department_id VARCHAR)
# question:Show the name and number of employees for the departments managed by heads whose temporary acting value is 'Yes'?
#
# assistant
# SELECT name, num_employees FROM department AS T1 JOIN management AS T2 ON T1.department_id = T2.department_id WHERE T1.temporary_acting = 'Yes'
# question:Show the name
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE management (temporary_acting VARCHAR)
# question:How many acting statuses are there?
#
# assistant
# SELECT temporary_acting FROM management
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE management (department_id VARCHAR); CREATE TABLE department (department_id VARCHAR)
# question:How many departments are led by heads who are not mentioned?
#
# assistant
# SELECT COUNT(department_id) FROM management WHERE department_id NOT EXISTS (SELECT department_id FROM department WHERE department_id = "heads")
# question:How many departments are led by heads who are not mentioned?
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE head (age VARCHAR, head_id VARCHAR); CREATE TABLE management (head_id VARCHAR, temporary_acting VARCHAR)
# question:What are the distinct ages of the heads who are acting?
#
# assistant
# SELECT COUNT(head_id) FROM management AS T1 AS T2
# question:What are the distinct ages of the heads who are acting?
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE management (department_id VARCHAR, head_id VARCHAR); CREATE TABLE head (born_state VARCHAR, head_id VARCHAR); CREATE TABLE department (department_id VARCHAR, name VARCHAR)
# question:List the states where both the secretary of 'Treasury' department and the secretary of 'Homeland Security' were born.
#
# assistant
# SELECT T1.department_id, T2.name FROM management AS T1 JOIN head AS T2 ON T1.department_id = T2.department_id JOIN department AS T3 ON T1.head_id
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE management (department_id VARCHAR); CREATE TABLE department (department_id VARCHAR, name VARCHAR)
# question:Which department has more than 1 head at a time? List the id, name and the number of heads.
#
# assistant
# SELECT T1.department_id, T1.name, T1.number_of_heads FROM department AS T1 JOIN management AS T2 ON T1.department_id = T2.department_id GROUP BY T
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE head (head_id VARCHAR, name VARCHAR)
# question:Which head's name has the substring 'Ha'? List the id and name.
#
# assistant
# SELECT head_id, name FROM head AS head_id GROUP BY head_id ORDER BY head_id LIMIT 1
# question:Which head's name has the substring 'Ha'? List the id and name.
#
# ```
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE farm (Id VARCHAR)
# question:How many farms are there?
#
# assistant
# SELECT COUNT(*) FROM farm
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE farm (Total_Horses VARCHAR)
# question:List the total number of horses on farms in ascending order.
#
# assistant
# SELECT COUNT(Total_Horses) FROM farm GROUP BY Total_Horses ORDER BY COUNT(*) DESC LIMIT 1
# question:List the total number of horses on farms in ascending order.
#
# ```
#
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE farm_competition (Hosts VARCHAR, Theme VARCHAR)
# question:What are the hosts of competitions whose theme is not "Aliens"?
#
# assistant
# SELECT Hosts FROM farm_competition WHERE Theme = "Aliens"
# question:What are the hosts of competitions whose theme is not "Aliens"?
#
# You can find the answers by clicking on the "Answer" button.
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE farm_competition (Theme VARCHAR, YEAR VARCHAR)
# question:What are the themes of farm competitions sorted by year in ascending order?
#
# assistant
# SELECT Theme FROM farm_competition ORDER BY YEAR
#
# Question:What is the theme of farm competitions sorted by year in ascending order?
#
# ```
#
# # answer  #
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE farm (Working_Horses INTEGER, Total_Horses INTEGER)
# question:What is the average number of working horses of farms with more than 5000 total number of horses?
#
# assistant
# SELECT AVG(Working_Horses) FROM farm WHERE Total_Horses > 5000
# Question:What is the average number of working horses of farms with more than 5000 total number of horses?
#
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE farm (Cows INTEGER)
# question:What are the maximum and minimum number of cows across all farms.
#
# assistant
# SELECT MAX(Cows) FROM farm
# #queryset
# #aggregate
# # # # # #
# # # # # #
# # # # # #
# # # # # #
# # # # # #
# # # #
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE city (Status VARCHAR)
# question:How many different statuses do cities have?
#
# assistant
# SELECT COUNT(*) FROM city WHERE Status = 'Status'
# #
# #
# #
# #
# #
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE city (Official_Name VARCHAR, Population VARCHAR)
# question:List official names of cities in descending order of population.
#
# assistant
# SELECT Official_Name FROM city ORDER BY Population
# question:List the names of cities in descending order of population.
#
# You can find the names of cities in descending order of population by using the `SELECT` operator.
#
# ```
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE city (Official_Name VARCHAR, Status VARCHAR, Population VARCHAR)
# question:List the official name and status of the city with the largest population.
#
# assistant
# SELECT Official_Name, Status FROM city WHERE Population > 10000000000000000000000000000000000000
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE city (Official_Name VARCHAR, City_ID VARCHAR); CREATE TABLE farm_competition (Year VARCHAR, Host_city_ID VARCHAR)
# question:Show the years and the official names of the host cities of competitions.
#
# assistant
# SELECT T2.Year, T2.Official_Name FROM city AS T1 JOIN farm_competition AS T2 ON T1.City_ID = T2.City_ID
# question:Show the years and the official names
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE farm_competition (Host_city_ID VARCHAR); CREATE TABLE city (Official_Name VARCHAR, City_ID VARCHAR)
# question:Show the official names of the cities that have hosted more than one competition.
#
# assistant
# SELECT Official_Name FROM city WHERE City_ID = "Houston"
# question:Show the names of the cities that have hosted more than one competition.
#
# #
# #
# #
# #
# #
# #
# #
# #
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE city (Status VARCHAR, City_ID VARCHAR); CREATE TABLE farm_competition (Host_city_ID VARCHAR)
# question:Show the status of the city that has hosted the greatest number of competitions.
#
# assistant
# SELECT Status FROM city WHERE City_ID = "Houston"
# question:Show the status of the city that has hosted the greatest number of competitions.
#
# ```
#
# Your code should pass the following test case:
#
# ```python
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE city (City_ID VARCHAR, Population INTEGER); CREATE TABLE farm_competition (Theme VARCHAR, Host_city_ID VARCHAR)
# question:Please show the themes of competitions with host cities having populations larger than 1000.
#
# assistant
# SELECT T2.Theme FROM city AS T1 JOIN farm_competition AS T2 ON T1.Host_city_ID = T2.Host_city_ID WHERE T1.Population > 1000
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE city (Status VARCHAR, Population INTEGER)
# question:Please show the different statuses of cities and the average population of cities with each status.
#
# assistant
# SELECT Status, AVG(Population) FROM city AS T1 JOIN city AS T2 ON T1.Status = T2.Status
# #queried:SELECT Status FROM city AS T1 JOIN city AS T2 ON T1
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE city (Status VARCHAR)
# question:Please show the different statuses, ordered by the number of cities that have each.
#
# assistant
# SELECT Status FROM city ORDER BY COUNT(*) DESC LIMIT 1
#
# Question:What is the status of the city with 100 cities?
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE city (Status VARCHAR)
# question:List the most common type of Status across cities.
#
# assistant
# SELECT Status FROM city GROUP BY Status ORDER BY COUNT(*) DESC LIMIT 1
#
# Question:List the most common type of Status across cities.
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE farm_competition (Official_Name VARCHAR, City_ID VARCHAR, Host_city_ID VARCHAR); CREATE TABLE city (Official_Name VARCHAR, City_ID VARCHAR, Host_city_ID VARCHAR)
# question:List the official names of cities that have not held any competition.
#
# assistant
# SELECT Official_Name FROM city WHERE City_ID IS NOT NULL AND Host_city_ID IS NOT IN (SELECT City_ID FROM city WHERE City_ID = "Not-Housed" AND Host_city_ID = "Not-
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE city (Status VARCHAR, Population INTEGER)
# question:Show the status shared by cities with population bigger than 1500 and smaller than 500.
#
# assistant
# SELECT Status FROM city WHERE Population > 1500 AND Population < 500
# question:Show the status shared by cities with population bigger than 1500 and smaller than 500.
#
# ```
#
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE city (Official_Name VARCHAR, Population VARCHAR)
# question:Find the official names of cities with population bigger than 1500 or smaller than 500.
#
# assistant
# SELECT Official_Name FROM city WHERE Population > 1500 AND Population < 500
# question:Find the official names of cities with population bigger than 1500 or smaller than 500.
#
# ```
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE city (Census_Ranking VARCHAR, Status VARCHAR)
# question:Show the census ranking of cities whose status are not "Village".
#
# assistant
# SELECT COUNT(Census_Ranking) FROM city WHERE Status = "Village"
# question:Show the census ranking of cities whose status is not "Village".
#
# ```
#
# Your code should pass the following test
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE courses (course_name VARCHAR, course_id VARCHAR); CREATE TABLE student_course_registrations (course_Id VARCHAR)
# question:which course has most number of registered students?
#
# assistant
# SELECT course_name FROM courses ORDER BY course_id LIMIT 1
# question:what is the total number of courses registered?
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE student_course_registrations (student_id VARCHAR)
# question:what is id of students who registered some courses but the least number of courses in these students?
#
# assistant
# SELECT COUNT(student_id) FROM student_course_registrations WHERE course_registrations < 10
# question:what is the number of courses in the least number of courses in these students?
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE candidates (candidate_id VARCHAR); CREATE TABLE people (first_name VARCHAR, last_name VARCHAR, person_id VARCHAR)
# question:what are the first name and last name of all candidates?
#
# assistant
# SELECT T1.first_name, T1.last_name FROM candidates AS T1 JOIN people AS T2 ON T1.person_id = T2.person_id JOIN candidates AS T3 ON T1.candidate
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE student_course_attendance (student_id VARCHAR); CREATE TABLE students (student_id VARCHAR)
# question:List the id of students who never attends courses?
#
# assistant
# SELECT T1.student_id FROM student_course_attendance AS T1 JOIN students AS T2 ON T1.student_id = T2.student_id WHERE T2.course_attendance_id =
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE student_course_attendance (student_id VARCHAR)
# question:List the id of students who attended some courses?
#
# assistant
# SELECT student_id FROM student_course_attendance WHERE student_id = "Student_Course Attendance"
# question:List the id of students who attended some courses?
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE courses (course_name VARCHAR, course_id VARCHAR); CREATE TABLE student_course_registrations (student_id VARCHAR, course_id VARCHAR)
# question:What are the ids of all students for courses and what are the names of those courses?
#
# assistant
# SELECT COUNT(course_id) FROM student_course_registrations AS T1 AS T2
# question:What is the total number of courses for all students?
#
# You can find the answers by clicking on the "Answer"
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE student_course_registrations (student_id VARCHAR, registration_date VARCHAR); CREATE TABLE students (student_details VARCHAR, student_id VARCHAR)
# question:What is detail of the student who most recently registered course?
#
# assistant
# SELECT student_details FROM students WHERE student_id <> 2000000000000000000000000000000000000
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE student_course_attendance (course_id VARCHAR); CREATE TABLE courses (course_id VARCHAR, course_name VARCHAR)
# question:How many students attend course English?
#
# assistant
# SELECT COUNT(course_id) FROM courses WHERE course_name = "English"
# question:How many courses attend English?
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE courses (course_id VARCHAR); CREATE TABLE student_course_attendance (course_id VARCHAR, student_id VARCHAR)
# question:How many courses do the student whose id is 171 attend?
#
# assistant
# SELECT COUNT(course_id) FROM student_course_attendance WHERE course_id = 171
# question:How many courses do the student whose id is 171 attend?
#
# You can do it by
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE candidates (candidate_id VARCHAR); CREATE TABLE people (person_id VARCHAR, email_address VARCHAR)
# question:Find id of the candidate whose email is stanley.monahan@example.org?
#
# assistant
# SELECT id FROM candidates WHERE person_id = "stanley.monahan@example.org"
# question:Find id of the candidate whose email is stanley.monahan@example.org?
#
# ```
#
# Your code should
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE candidate_assessments (candidate_id VARCHAR, assessment_date VARCHAR)
# question:Find id of the candidate who most recently accessed the course?
#
# assistant
# SELECT candidate_id FROM candidate_assessments WHERE assessment_date = "2019-01-01"
# question:What is the candidate's ID?
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE students (student_details VARCHAR, student_id VARCHAR); CREATE TABLE student_course_registrations (student_id VARCHAR)
# question:What is detail of the student who registered the most number of courses?
#
# assistant
# SELECT student_details FROM student_course_registrations AS T1 WHERE student_id = 1
# question:What is the detail of the student who registered the most number of courses?
#
# ```
#
# result:SELECT student_
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE students (student_id VARCHAR); CREATE TABLE student_course_registrations (student_id VARCHAR)
# question:List the id of students who registered some courses and the number of their registered courses?
#
# assistant
# SELECT T1.student_id FROM student_course_registrations AS T1 JOIN students AS T2 ON T1.student_id = T2.student_id WHERE T2.course_registrations = "Some
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE students (student_id VARCHAR); CREATE TABLE courses (course_name VARCHAR, course_id VARCHAR); CREATE TABLE student_course_registrations (course_id VARCHAR, student_id VARCHAR)
# question:How many registed students do each course have? List course name and the number of their registered students?
#
# assistant
# SELECT COUNT(student_id) FROM courses ORDER BY course_name LIMIT 1
# question:How many students do each course have? List course name and the number of their registered students?
#
# ```
#
# Your code should pass
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE candidate_assessments (candidate_id VARCHAR, asessment_outcome_code VARCHAR)
# question:Find id of candidates whose assessment code is "Pass"?
#
# assistant
# SELECT candidate_id FROM candidate_assessments WHERE asessment_outcome_code = "Pass"
# question:What is the candidate ID?
#
# ```
#
# Your code should be as unique as possible.
#
# ```
# SELECT
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE candidates (candidate_id VARCHAR); CREATE TABLE people (cell_mobile_number VARCHAR, person_id VARCHAR); CREATE TABLE candidate_assessments (candidate_id VARCHAR, asessment_outcome_code VARCHAR)
# question:Find the cell mobile number of the candidates whose assessment code is "Fail"?
#
# assistant
# SELECT cell_mobile_number FROM candidates WHERE asessment_outcome_code = "Fail"
# question:What is the cell mobile number of the candidates whose assessment code is "Fail"?
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE student_course_attendance (student_id VARCHAR, course_id VARCHAR)
# question:What are the id of students who registered course 301?
#
# assistant
# SELECT student_id FROM student_course_attendance WHERE course_id = 301
# question:What is the id of students who registered course 301?
#
# SELECT student_id FROM student_course_att
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE student_course_attendance (student_id VARCHAR, course_id VARCHAR, date_of_attendance VARCHAR)
# question:What is the id of the student who most recently registered course 301?
#
# assistant
# SELECT student_id FROM student_course_attendance WHERE course_id = 301 AND date_of_attendance = "301"
# question:What is the id of the student who most recently registered course
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE addresses (city VARCHAR, address_id VARCHAR); CREATE TABLE people_addresses (address_id VARCHAR)
# question:Find distinct cities of addresses of people?
#
# assistant
# SELECT COUNT(city) FROM people_addresses AS T1 JOIN addresses AS T2 ON T1.city = T2.address_id WHERE T2.address_id = T1.address_id
# question:What
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE students (student_id VARCHAR); CREATE TABLE addresses (city VARCHAR, address_id VARCHAR); CREATE TABLE people_addresses (address_id VARCHAR, person_id VARCHAR)
# question:Find distinct cities of address of students?
#
# assistant
# SELECT COUNT(DISTINCT city) FROM people_addresses AS T1 AS T2
# # SELECT COUNT(DISTINCT city) FROM people_addresses AS T1 AS T2
# # Lake Tahoe,
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE courses (course_name VARCHAR)
# question:List the names of courses in alphabetical order?
#
# assistant
# SELECT course_name FROM courses ORDER BY course_name LIMIT 1
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE people (first_name VARCHAR)
# question:List the first names of people in alphabetical order?
#
# assistant
# SELECT first_name FROM people ORDER BY first_name LIMIT 1
# question:List the first names of people in alphabetical order?
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE student_course_attendance (student_id VARCHAR); CREATE TABLE student_course_registrations (student_id VARCHAR)
# question:What are the id of students who registered courses or attended courses?
#
# assistant
# SELECT T1.student_id FROM student_course_registrations AS T1 JOIN student_course_attendance AS T2 ON T1.student_id = T2.student_id JOIN student_course_
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE student_course_attendance (course_id VARCHAR, student_id VARCHAR); CREATE TABLE student_course_registrations (course_id VARCHAR, student_id VARCHAR)
# question:Find the id of courses which are registered or attended by student whose id is 121?
#
# assistant
# SELECT COUNT(course_id) FROM student_course_registrations WHERE student_id = 121
# question:What is the id of courses which are registered or attended by student whose id is 121?
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE student_course_attendance (student_id VARCHAR); CREATE TABLE student_course_registrations (student_id VARCHAR)
# question:What are all info of students who registered courses but not attended courses?
#
# assistant
# SELECT T1.student_id FROM student_course_registrations AS T1 JOIN student_course_attendance AS T2 ON T1.student_id = T2.student_id JOIN student_course_
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE student_course_registrations (student_id VARCHAR, course_id VARCHAR, registration_date VARCHAR); CREATE TABLE courses (course_id VARCHAR, course_name VARCHAR)
# question:List the id of students who registered course statistics in the order of registration date.
#
# assistant
# SELECT T1.student_id FROM courses AS T1 JOIN student_course_registrations AS T2 ON T1.student_id = T2.student_id GROUP BY T1.student_id ORDER BY
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE student_course_attendance (student_id VARCHAR, course_id VARCHAR, date_of_attendance VARCHAR); CREATE TABLE courses (course_id VARCHAR, course_name VARCHAR)
# question:List the id of students who attended  statistics courses in the order of attendance date.
#
# assistant
# SELECT COUNT(course_id) FROM courses WHERE course_name = "Statistics"
# question:List the id of students who attended  statistics courses in the order of attendance date.
#
# ```
#
# Your code should pass the following test
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE weather (date VARCHAR, max_temperature_f INTEGER)
# question:Give me the dates when the max temperature was higher than 85.
#
# assistant
# SELECT date FROM weather WHERE max_temperature_f > 85
# question:What is the date when the max temperature is 85?
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE station (name VARCHAR, lat INTEGER)
# question:What are the names of stations that have latitude lower than 37.5?
#
# assistant
# SELECT name FROM station WHERE lat < 37.5
# question:What are the names of stations that have lat greater than 37.5?
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE station (city VARCHAR, lat INTEGER)
# question:For each city, return the highest latitude among its stations.
#
# assistant
# SELECT city, MAX(lat) FROM station GROUP BY city
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE trip (start_station_name VARCHAR, end_station_name VARCHAR, id VARCHAR)
# question:Give me the start station and end station for the trips with the three oldest id.
#
# assistant
# SELECT start_station_name FROM trip WHERE end_station_name = "3rd" AND id = "3"
# question:What is the start station and end station for the trips with the three oldest id.
#
# ```
#
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE station (lat INTEGER, long INTEGER, city VARCHAR)
# question:What is the average latitude and longitude of stations located in San Jose city?
#
# assistant
# SELECT AVG(lat) FROM station WHERE long > 10000000000000000000000000000000000000
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE trip (id VARCHAR, duration VARCHAR)
# question:What is the id of the trip that has the shortest duration?
#
# assistant
# SELECT id FROM trip WHERE duration < 1000
# question:What is the id of the trip that has the shortest duration?
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE trip (duration INTEGER, bike_id VARCHAR)
# question:What is the total and maximum duration of trips with bike id 636?
#
# assistant
# SELECT MAX(duration) FROM trip WHERE bike_id = 636
# #
# # Question:What is the total and maximum duration of trips with bike id 636?
# #
# # Question:What is the total and
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE weather (zip_code VARCHAR, mean_temperature_f INTEGER, date VARCHAR)
# question:For each zip code, return the average mean temperature of August there.
#
# assistant
# SELECT AVG(mean_temperature_f) FROM weather WHERE zip_code = "August"
# # Output
# SELECT AVG(mean_temperature_f) FROM weather WHERE zip_code = "August"
# # Question
#
# #
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE trip (bike_id VARCHAR)
# question:From the trip record, find the number of unique bikes.
#
# assistant
# SELECT COUNT(trip_id) FROM trip
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE station (city VARCHAR)
# question:What is the number of distinct cities the stations are located at?
#
# assistant
# SELECT COUNT(distinct city) FROM station
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE station (city VARCHAR)
# question:How many stations does Mountain View city has?
#
# assistant
# SELECT COUNT(*) FROM station GROUP BY city
#
#
# # EXTERNAL LANGUAGES
# # Lake Tahoe, California
# # Lake Tahoe, California
# # Lake Tahoe, California
# # Lake Tahoe,
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE station (name VARCHAR, id VARCHAR); CREATE TABLE status (station_id VARCHAR, bikes_available VARCHAR)
# question:Return the unique name for stations that have ever had 7 bikes available.
#
# assistant
# SELECT T1.name FROM station AS T1 JOIN status AS T2 ON T1.station_id = T2.id JOIN station_id AS T3 ON T1.id = T3.station_id WHERE T
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE trip (start_station_name VARCHAR, start_station_id VARCHAR, start_date VARCHAR)
# question:Which start station had the most trips starting from August? Give me the name and id of the station.
#
# assistant
# SELECT start_station_name, start_station_id FROM trip WHERE start_station_id = "August"
# question:What is the name of the start station that started on August 10, 2007?
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE trip (bike_id VARCHAR, zip_code VARCHAR)
# question:Which bike traveled the most often in zip code 94002?
#
# assistant
# SELECT bike_id FROM trip WHERE zip_code = "94002"
# question:Which bike traveled the most often in zip code 94002?
#
# ```
#
# Your code should pass the following test:
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE weather (mean_humidity VARCHAR, mean_visibility_miles VARCHAR)
# question:How many days had both mean humidity above 50 and mean visibility above 8?
#
# assistant
# SELECT COUNT(mean_humidity) FROM weather WHERE mean_humidity > 50 AND mean_visibility_miles > 8
# Question:How many days had both mean humidity above 50 and mean visibility above
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE trip (start_station_id VARCHAR, duration VARCHAR); CREATE TABLE station (lat VARCHAR, long VARCHAR, city VARCHAR, id VARCHAR)
# question:What is the latitude, longitude, city of the station from which the shortest trip started?
#
# assistant
# SELECT start_station_id, LAT, LONG, city FROM trip WHERE LAT > 10000000000000000000000000000
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE status (id VARCHAR, station_id VARCHAR, city VARCHAR, bikes_available INTEGER); CREATE TABLE station (id VARCHAR, station_id VARCHAR, city VARCHAR, bikes_available INTEGER)
# question:What are the ids of stations that are located in San Francisco and have average bike availability above 10.
#
# assistant
# SELECT COUNT(status.id) FROM status AS i JOIN station AS j ON i.station_id = j.station_id WHERE j.bikes_available > 10 AND j.city = 'San Francisco' AND
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE station (name VARCHAR, id VARCHAR); CREATE TABLE station (name VARCHAR, id VARCHAR, installation_date VARCHAR); CREATE TABLE status (station_id VARCHAR, bikes_available INTEGER)
# question:What are the names and ids of stations that had more than 14 bikes available on average or were installed in December?
#
# assistant
# SELECT T1.name, T2.id FROM station AS T1 JOIN status AS T2 ON T1.station_id = T2.id JOIN station_id ON T1.id = T2.id WHERE T
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE weather (cloud_cover VARCHAR, zip_code VARCHAR)
# question:What is the 3 most common cloud cover rates in the region of zip code 94107?
#
# assistant
# SELECT 3 AS cloud_cover FROM weather WHERE zip_code = "94107"
# question:What is the 3 most common cloud cover rates in the region of zip code 94107?
#
# Answer
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE weather (zip_code VARCHAR, mean_sea_level_pressure_inches INTEGER)
# question:What is the zip code in which the average mean sea level pressure is the lowest?
#
# assistant
# SELECT zip_code FROM weather WHERE mean_sea_level_pressure_inches < 0
# question:What is the zip code in which the average mean sea level pressure is the lowest?
#
# ```
#
# Your code should pass the following
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE status (bikes_available INTEGER, station_id VARCHAR, id VARCHAR, city VARCHAR); CREATE TABLE station (bikes_available INTEGER, station_id VARCHAR, id VARCHAR, city VARCHAR)
# question:What is the average bike availability in stations that are not located in Palo Alto?
#
# assistant
# SELECT AVG(bikes_available) FROM station WHERE station_id NOT IN (1) AND city = "Palo Alto"
# question:What is the average bike availability in stations that are not located in Palo Alto?
#
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE station (long INTEGER, id VARCHAR, station_id VARCHAR, bikes_available INTEGER); CREATE TABLE status (long INTEGER, id VARCHAR, station_id VARCHAR, bikes_available INTEGER)
# question:What is the average longitude of stations that never had bike availability more than 10?
#
# assistant
# SELECT AVG(long) FROM station WHERE station_id IN (SELECT id FROM status) AND bikes_available > 10
# Question:What is the average longitude of stations that never had bike availability more than 10?
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE weather (date VARCHAR, zip_code VARCHAR, max_temperature_f VARCHAR)
# question:When and in what zip code did max temperature reach 80?
#
# assistant
# SELECT date, zip_code FROM weather WHERE max_temperature_f = "80"
# Question:When and in what zip code did max temperature reach 80?
#
# ```
#
# Your code should pass the following test case:
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE trip (id VARCHAR, zip_code VARCHAR); CREATE TABLE weather (zip_code VARCHAR, mean_temperature_f INTEGER)
# question:Give me ids for all the trip that took place in a zip code area with average mean temperature above 60.
#
# assistant
# SELECT T1.id FROM trip AS T1 JOIN weather AS T2 ON T1.zip_code = T2.zip_code WHERE T2.mean_temperature_f > 60
# question:Give me ids for
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE weather (zip_code VARCHAR, max_wind_Speed_mph VARCHAR)
# question:For each zip code, return how many times max wind speed reached 25?
#
# assistant
# SELECT COUNT(zip_code) FROM weather WHERE max_wind_Speed_mph = "25"
# question:For each zip code, return how many times max wind speed reached 25?
#
# ```
#
# Your code
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE weather (date VARCHAR, zip_code VARCHAR, min_dew_point_f INTEGER)
# question:On which day and in which zip code was the min dew point lower than any day in zip code 94107?
#
# assistant
# SELECT date FROM weather WHERE min_dew_point_f < 94107 ORDER BY date
#
# Question:On which day and in which zip code was the min dew point lower than any day in zip code 9
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE station (installation_date VARCHAR, id VARCHAR); CREATE TABLE trip (id VARCHAR, end_station_id VARCHAR)
# question:For each trip, return its ending station's installation date.
#
# assistant
# SELECT T1.end_station_id, T2.installation_date FROM station AS T1 JOIN trip AS T2 ON T1.id = T2.id JOIN station_id ON T1.id = T
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE trip (id VARCHAR, start_station_id VARCHAR); CREATE TABLE station (id VARCHAR, dock_count VARCHAR)
# question:Which trip started from the station with the largest dock count? Give me the trip id.
#
# assistant
# SELECT T1.id, T2.start_station_id FROM trip AS T1 JOIN station AS T2 ON T1.id = T2.id WHERE T1.start_station_id = "Dock"
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE trip (end_station_id VARCHAR); CREATE TABLE station (id VARCHAR, city VARCHAR)
# question:Count the number of trips that did not end in San Francisco city.
#
# assistant
# SELECT COUNT(trip.id) FROM trip AS T JOIN station AS T ON T.city = T.end_station_id
# question:What is the total number of trips that did not end in San Francisco city?
#
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE weather (date VARCHAR, EVENTS VARCHAR, zip_code VARCHAR)
# question:In zip code 94107, on which day neither Fog nor Rain was not observed?
#
# assistant
# SELECT date FROM weather WHERE EVENTS NOT EXISTS WHERE zip_code = "94107"
# question:In zip code 94107, on which day neither Fog nor Rain was not observed?
#
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE status (id VARCHAR, station_id VARCHAR, lat INTEGER, bikes_available INTEGER); CREATE TABLE station (id VARCHAR, station_id VARCHAR, lat INTEGER, bikes_available INTEGER)
# question:What are the ids of stations that have latitude above 37.4 and never had bike availability below 7?
#
# assistant
# SELECT T1.id FROM status AS T1 JOIN station AS T2 ON T1.station_id = T2.station_id WHERE T1.lat > 37.4 AND T1.bikes_available <
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE station (name VARCHAR, id VARCHAR); CREATE TABLE status (station_id VARCHAR); CREATE TABLE station (name VARCHAR, city VARCHAR, bikes_available INTEGER)
# question:What are names of stations that have average bike availability above 10 and are not located in San Jose city?
#
# assistant
# SELECT name FROM station WHERE city = "San Jose" AND bikes_available > 10
# question:What are the names of stations that have average bike availability above 10 and are not located in San Jose city?
#
# ```
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE station (name VARCHAR, lat VARCHAR, city VARCHAR)
# question:What are the name, latitude, and city of the station with the lowest latitude?
#
# assistant
# SELECT name, lat, city FROM station WHERE lat < 0 ORDER BY name
# question:What are the name, latitude, and city of the station with the lowest latitude?
#
# ```
#
# Your code should pass the following test case
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE weather (date VARCHAR, mean_temperature_f VARCHAR, mean_humidity VARCHAR, max_gust_speed_mph VARCHAR)
# question:What are the date, mean temperature and mean humidity for the top 3 days with the largest max gust speeds?
#
# assistant
# SELECT date, mean_temperature_f, mean_humidity FROM weather WHERE max_gust_speed_mph = "top 3"
# question:What is the date, mean temperature and mean humidity for the top 3 days with
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE station (city VARCHAR)
# question:List the name and the number of stations for all the cities that have at least 15 stations.
#
# assistant
# SELECT city, MIN(station) FROM station
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE trip (start_station_id VARCHAR, start_station_name VARCHAR)
# question:Find the ids and names of stations from which at least 200 trips started.
#
# assistant
# SELECT start_station_id, start_station_name FROM trip WHERE start_station_id = 200
# question:What is the start station name?
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE weather (zip_code VARCHAR, mean_visibility_miles INTEGER)
# question:Find the zip code in which the average mean visibility is lower than 10.
#
# assistant
# SELECT zip_code FROM weather WHERE mean_visibility_miles < 10
# Question:Find the zip code in which the average mean visibility is lower than 10.
#
# ```
#
# Your code should pass the following test
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE station (city VARCHAR, lat INTEGER)
# question:List all the cities in a decreasing order of each city's stations' highest latitude.
#
# assistant
# SELECT city FROM station ORDER BY lat DESC LIMIT 1
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE weather (date VARCHAR, cloud_cover VARCHAR)
# question:What are the dates that had the top 5 cloud cover rates? Also tell me the cloud cover rate.
#
# assistant
# SELECT date, cloud_cover FROM weather WHERE cloud_cover > 5
# # Lake Tahoe, California
# # Lake Tahoe, California
# # Lake Tahoe, California
# # Lake Tahoe, California
#
# SELECT date FROM weather WHERE
# \
# user
# ...
#
# assistant
# SELECT MAX(followers) FROM user_profiles;
# ```
#
# Output:The maximum and total number of followers of all users are 10.
#
# Your code should pass the test case "SELECT MAX(followers) FROM
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE catalog_contents (catalog_entry_name VARCHAR)
# question:Find the names of all the catalog entries.
#
# assistant
# SELECT catalog_entry_name FROM catalog_contents
# question:Find the names of all the catalog entries.
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE Attribute_Definitions (attribute_data_type VARCHAR)
# question:Find the list of attribute data types possessed by more than 3 attribute definitions.
#
# assistant
# SELECT attribute_data_type FROM Attribute_Definitions ORDER BY attribute_data_type DESC LIMIT 3
# question:Find the list of attribute data types possessed by more than 3 attribute definitions.
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE Attribute_Definitions (attribute_data_type VARCHAR, attribute_name VARCHAR)
# question:What is the attribute data type of the attribute with name "Green"?
#
# assistant
# SELECT attribute_data_type FROM Attribute_Definitions WHERE attribute_name = "Green"
# question:What is the attribute data type of the attribute with name "Green"?
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE Catalog_Structure (catalog_level_name VARCHAR, catalog_level_number INTEGER)
# question:Find the name and level of catalog structure with level between 5 and 10.
#
# assistant
# SELECT catalog_level_name, catalog_level_number FROM Catalog_Structure WHERE catalog_level_name < 5 AND catalog_level_number > 10
# question:What is the catalog level name?
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE catalogs (catalog_publisher VARCHAR)
# question:Find all the catalog publishers whose name contains "Murray"
#
# assistant
# SELECT catalog_publisher FROM catalogs WHERE catalog_publisher = "Murray"
# question:What is the catalog publisher?
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE catalogs (catalog_publisher VARCHAR)
# question:Which catalog publisher has published the most catalogs?
#
# assistant
# SELECT catalog_publisher FROM catalogs
# #queryset
# #returned 1
# #showing the catalog publisher
# #showing the catalog publisher
# #showing the catalog publisher
# #showing the catalog publisher
# #showing the
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE catalogs (catalog_name VARCHAR, date_of_publication VARCHAR, catalog_id VARCHAR); CREATE TABLE catalog_structure (catalog_id VARCHAR)
# question:Find the names and publication dates of all catalogs that have catalog level number greater than 5.
#
# assistant
# SELECT T1.catalog_name, T1.catalog_id FROM catalogs AS T1 JOIN catalog_structure AS T2 ON T1.catalog_id = T2.catalog_id GROUP BY T1.catalog_name
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE Catalog_Contents_Additional_Attributes (catalog_entry_id VARCHAR, attribute_value VARCHAR); CREATE TABLE Catalog_Contents (catalog_entry_name VARCHAR, catalog_entry_id VARCHAR); CREATE TABLE Catalog_Contents_Additional_Attributes (attribute_value VARCHAR)
# question:What are the entry names of catalog with the attribute possessed by most entries.
#
# assistant
# SELECT T1.catalog_entry_name FROM Catalog_Contents AS T1 JOIN Catalog_Contents AS T2 ON T1.catalog_entry_id = T2.catalog_entry_id WHERE T2.attribute_value =
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE catalog_contents (catalog_entry_name VARCHAR, price_in_dollars VARCHAR)
# question:What is the entry name of the most expensive catalog (in USD)?
#
# assistant
# SELECT catalog_entry_name FROM catalog_contents AS T1 JOIN catalog_contents AS T2 ON T1.catalog_entry_name = T2.catalog_entry_name WHERE T2.price_in_dollars
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE catalog_structure (catalog_level_name VARCHAR, catalog_level_number VARCHAR); CREATE TABLE catalog_contents (catalog_level_number VARCHAR, price_in_dollars VARCHAR)
# question:What is the level name of the cheapest catalog (in USD)?
#
# assistant
# SELECT COUNT(catalog_level_name) FROM catalog_structure WHERE catalog_level_number = "CUSTOMER"
# question:What is the lowest price in USD?
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE catalog_contents (price_in_euros INTEGER)
# question:What are the average and minimum price (in Euro) of all products?
#
# assistant
# SELECT AVG(price_in_euros) FROM catalog_contents WHERE price_in_euros = "1.0"
# question:What are the average and minimum price (in Euro) of all products?
#
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE catalog_contents (catalog_entry_name VARCHAR, height VARCHAR)
# question:What is the product with the highest height? Give me the catalog entry name.
#
# assistant
# SELECT catalog_entry_name FROM catalog_contents WHERE height > 100
# question:What is the catalog entry name?
#
# ```
#
# Your code should pass the following test case:
#
# ```python
# catalog_contents =
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE catalog_contents (catalog_entry_name VARCHAR, capacity VARCHAR)
# question:Find the name of the product that has the smallest capacity.
#
# assistant
# SELECT catalog_entry_name FROM catalog_contents WHERE capacity < 1000000
# question:Find the name of the product that has the smallest capacity.
#
# ```
#
# Your code should pass the following test case:
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE catalog_contents (catalog_entry_name VARCHAR, product_stock_number VARCHAR)
# question:Find the names of all the products whose stock number starts with "2".
#
# assistant
# SELECT catalog_entry_name FROM catalog_contents WHERE product_stock_number = "2"
# question:What is the catalog entry name of the products whose stock number starts with "2"?
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE Catalog_Contents_Additional_Attributes (catalog_entry_id VARCHAR, catalog_level_number VARCHAR); CREATE TABLE Catalog_Contents (catalog_entry_name VARCHAR, catalog_entry_id VARCHAR)
# question:Find the names of catalog entries with level number 8.
#
# assistant
# SELECT COUNT(*) FROM Catalog_Contents WHERE catalog_entry_name = "8"
# question:What is the name of the catalog entry with level number 8?
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE catalog_contents (catalog_entry_name VARCHAR, LENGTH VARCHAR, width VARCHAR)
# question:Find the names of the products with length smaller than 3 or height greater than 5.
#
# assistant
# SELECT catalog_entry_name FROM catalog_contents WHERE LENGTH < 3 AND WIDTH > 5
# question:Find the names of the products with length smaller than 3 or height greater than 5.
#
# ```
#
#
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE Catalog_Contents_Additional_Attributes (attribute_id VARCHAR, attribute_value VARCHAR); CREATE TABLE Attribute_Definitions (attribute_name VARCHAR, attribute_id VARCHAR)
# question:Find the name and attribute ID of the attribute definitions with attribute value 0.
#
# assistant
# SELECT T1.attribute_name, T1.attribute_value FROM Attribute_Definitions AS T1 JOIN Catalog_Contents_Additional_Attributes AS T2 ON T1.attribute_id = T2.attribute_id JOIN
# \
# user
# You are a SQL expert. Given the Schema, generate ONLY the SQL query without any explanations or markdown formatting.
# Schema:CREATE TABLE Catalog_Contents (catalog_entry_name VARCHAR, capacity VARCHAR, price_in_dollars INTEGER)
# question:Find the name and capacity of products with price greater than 700 (in USD).
#
# assistant
# SELECT catalog_entry_name, capacity FROM Catalog_Contents WHERE price_in_dollars > 700
# question:What is the name of the catalog entry with a price greater than 700?
#
# ```
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-589189c40505> in <cell line: 49>()
#      51     context = row["context"]
#      52     # output
# ---> 53     generated_sql = finetune_response(question, context)
#      54     generated_sqls.append(generated_sql)
#      55
#
# <ipython-input-30-d1072c9fa90c> in finetune_response(question, context)
#      12   # Generate the output.
#      13   # output = model.generate(**inputs)
# ---> 14   outputs = model.generate(
#      15         inputs["input_ids"],
#      16         attention_mask=inputs["attention_mask"],  # Ensure attention mask is passed
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2213
#    2214             # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2215             result = self._sample(
#    2216                 input_ids,
#    2217                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3204
#    3205             # forward pass to get next token
# -> 3206             outputs = self(**model_inputs, return_dict=True)
#    3207
#    3208             # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, num_logits_to_keep, **loss_kwargs)
#    1188
#    1189         # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1190         outputs = self.model(
#    1191             input_ids=input_ids,
#    1192             attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     943                 )
#     944             else:
# --> 945                 layer_outputs = decoder_layer(
#     946                     hidden_states,
#     947                     attention_mask=causal_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position, position_embeddings, **kwargs)
#     689         # Fully Connected
#     690         residual = hidden_states
# --> 691         hidden_states = self.post_attention_layernorm(hidden_states)
#     692         hidden_states = self.mlp(hidden_states)
#     693         hidden_states = residual + hidden_states
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, hidden_states)
#      70         input_dtype = hidden_states.dtype
#      71         hidden_states = hidden_states.to(torch.float32)
# ---> 72         variance = hidden_states.pow(2).mean(-1, keepdim=True)
#      73         hidden_states = hidden_states * torch.rsqrt(variance + self.variance_epsilon)
#      74         return self.weight * hidden_states.to(input_dtype)
#
# KeyboardInterrupt:

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

# Reload model and tokenizer from Hugging Face Hub
model = AutoModelForSeq2SeqLM.from_pretrained("Hiyaj/bart-small-text2sql")
tokenizer = AutoTokenizer.from_pretrained("Hiyaj/bart-small-text2sql")

# Ensure the model is on the correct device
device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)
# Out:
# config.json:   0%|          | 0.00/1.72k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/558M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/292 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.34k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.56M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/957 [00:00<?, ?B/s]
# BartForConditionalGeneration(
#   (model): BartModel(
#     (shared): BartScaledWordEmbedding(50265, 768, padding_idx=1)
#     (encoder): BartEncoder(
#       (embed_tokens): BartScaledWordEmbedding(50265, 768, padding_idx=1)
#       (embed_positions): BartLearnedPositionalEmbedding(1026, 768)
#       (layers): ModuleList(
#         (0-5): 6 x BartEncoderLayer(
#           (self_attn): BartSdpaAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layernorm_embedding): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     )
#     (decoder): BartDecoder(
#       (embed_tokens): BartScaledWordEmbedding(50265, 768, padding_idx=1)
#       (embed_positions): BartLearnedPositionalEmbedding(1026, 768)
#       (layers): ModuleList(
#         (0-5): 6 x BartDecoderLayer(
#           (self_attn): BartSdpaAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartSdpaAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layernorm_embedding): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (lm_head): Linear(in_features=768, out_features=50265, bias=False)
# )
